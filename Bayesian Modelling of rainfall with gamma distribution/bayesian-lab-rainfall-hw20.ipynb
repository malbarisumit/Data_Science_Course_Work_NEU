# %% [markdown]
# <div style="text-align: right">INFO 6105 Data Science Eng Methods and Tools, Lecture 8 Day 2</div>
# <div style="text-align: right">Dino Konstantopoulos, 29 October 2020, with material from Philip Lewis</div>
#
# # Homework: Bayesian Modeling of Rainfall with the $\gamma$ distribution
#
# Let's practice what we learned. Let's build a **Bayesian model** for a dataset, so we can extract precise statistics from the model itself, rather than the data.
#
# You may use `PyMC3` or `Sampyl` for this homework.
#
# ### How to build a Bayesian model?
# * Look at the histogram of the data
# * Pick an analytic probability densiy function matching the shape of the histogram
# * Model its parameters (priors) as probability density functions
# * Try different shape and values of these parameters (these are called *hyperparameters*)
# * Run a probabilistic program to give us the posterior pdfs
# * Plot the posterior means on top of the histogram and check if we get a good match!
#
# We will model rainfall data per calendar month for the city of Nashville, Tennessee. Rainfall data is usually modelled with  the $\gamma$ distribution.
#
# <br />
# <center>
# <img src="ipynb.images/rainfall.jpeg" width=400 />
# </center>

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
sns.set_context('notebook')

RANDOM_SEED = 20090425

# %% [markdown]
# ## 1. The $\gamma$ distribution
#
# This is the [gamma distribution](https://en.wikipedia.org/wiki/Gamma_distribution):
#
# <div style="font-size: 120%;">
# $$\gamma(x) = \frac{\beta^\alpha x^{\alpha -1} e^{- \beta x}}{\Gamma (\alpha)}$$
# </div>
#
# How many parameters in the gamma function?
#
# What is the $\Gamma()$ function? It [interpolates](https://en.wikipedia.org/wiki/Gamma_function) the factorial function to non-integer values!
#
# This is what the $\gamma$ function for $x > 0$ and $\alpha, \beta > 0$ looks like:
#
# </br >
# <center>
# <img src="https://upload.wikimedia.org/wikipedia/commons/e/e6/Gamma_distribution_pdf.svg" width="500" />
# Gamma distribution
# </center>

# %% [markdown]
# ## 2. Dataset: Nashville Precipitation
#
# The dataset `nashville_precip.txt` contains NOAA precipitation data for Nashville measured since 1871. Download it from blackboard and put it in the right folder (`C:/Users/<username>/data`).
#
# The $\gamma$ distribution happens to be a good fit to aggregated rainfall data, and will be our candidate model in this case.
#
# Let's peek at the data:

# %%
precip = pd.read_table("data/nashville_precip.txt", index_col=0, na_values='NA', delim_whitespace=True)
precip.head()
# Out:
#        Jan   Feb   Mar    Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec
# Year
# 1871  2.76  4.58  5.01   4.13  3.30  2.98  1.58  2.36  0.95  1.31  2.13  1.65
# 1872  2.32  2.11  3.14   5.91  3.09  5.17  6.10  1.65  4.50  1.58  2.25  2.38
# 1873  2.96  7.14  4.11   3.59  6.31  4.20  4.63  2.36  1.81  4.28  4.36  5.94
# 1874  5.22  9.23  5.36  11.84  1.49  2.87  2.65  3.52  3.12  2.63  6.12  4.19
# 1875  6.15  3.06  8.14   4.22  1.73  5.63  8.12  1.60  3.79  1.25  5.46  4.30

# %% [markdown]
# Let's do some data exploration..

# %%
_ = precip.hist(sharex=True, sharey=True, grid=False)
plt.tight_layout()

# %% [markdown]
# The first step is recognizing what sort of distribution to fit our data to. A couple of observations:
#
# 1. The data is *skewed*, with a longer tail to the right than to the left
# 2. The data is *positive-valued*, since they are measuring rainfall
# 3. The data is *continuous*
#
# There are a few possible choices, but a good option is the [gamma distribution](https://en.wikipedia.org/wiki/Gamma_distribution). If $x$ measures rainfall:
#
# <div style="font-size: 120%;">
# $$x \sim \gamma(\alpha, \beta) = \frac{\beta^{\alpha}x^{\alpha-1}e^{-\beta x}}{\Gamma(\alpha)}$$
# </div>
#
# The gamma distribution is often used to model the size of [insurance claims](https://www.crcpress.com/Statistical-and-Probabilistic-Methods-in-Actuarial-Science/Boland/p/book/9781584886952) and [rainfalls](http://journals.tubitak.gov.tr/engineering/issues/muh-00-24-6/muh-24-6-7-9909-13.pdf). This means that aggregate insurance claims and the amount of rainfall accumulated in a reservoir are usually well modelled by a gamma process.

# %% [markdown]
# ## 3. Data Cleansing
#
# Wait a sec.. There's something wrong with our data.. if you open it in a text editor, you will find a value of NA for October of 1963 (take a look!). So we have to do some data cleansing first (remember the first step in data science from Lecture 1?). Given what we are trying to do, it is sensible to fill in the missing value with the **average of the available values** (another option would have been the average of the months of September and November 1963).

# %%
precip.fillna(value={'Oct': precip.Oct.mean()}, inplace=True)
precip
# Out:
#        Jan   Feb   Mar    Apr    May   Jun   Jul   Aug    Sep   Oct   Nov  \
# Year
# 1871  2.76  4.58  5.01   4.13   3.30  2.98  1.58  2.36   0.95  1.31  2.13
# 1872  2.32  2.11  3.14   5.91   3.09  5.17  6.10  1.65   4.50  1.58  2.25
# 1873  2.96  7.14  4.11   3.59   6.31  4.20  4.63  2.36   1.81  4.28  4.36
# 1874  5.22  9.23  5.36  11.84   1.49  2.87  2.65  3.52   3.12  2.63  6.12
# 1875  6.15  3.06  8.14   4.22   1.73  5.63  8.12  1.60   3.79  1.25  5.46
# ...    ...   ...   ...    ...    ...   ...   ...   ...    ...   ...   ...
# 2007  3.32  1.84  2.26   2.75   3.30  2.37  1.47  1.38   1.99  4.95  6.20
# 2008  4.76  2.53  5.56   7.20   5.54  2.21  4.32  1.67   0.88  5.03  1.75
# 2009  4.59  2.85  2.92   4.13   8.45  4.53  6.03  2.14  11.08  6.49  0.67
# 2010  4.13  2.77  3.52   3.48  16.43  4.96  5.86  6.99   1.17  2.49  5.41
# 2011  2.31  5.54  4.59   7.51   4.38  5.04  3.46  1.78   6.20  0.93  6.15
#
#        Dec
# Year
# 1871  1.65
# 1872  2.38
# 1873  5.94
# 1874  4.19
# 1875  4.30
# ...    ...
# 2007  3.83
# 2008  6.72
# 2009  3.99
# 2010  1.87
# 2011  4.25
#
# [141 rows x 12 columns]

# %% [markdown]
# ## 4. Exploration
#
# Let's calculate the **means** and **variances** of precipitation, month by month:

# %%
precip_mean = precip.mean()
precip_mean
# Out:
# Jan    4.523688
# Feb    4.097801
# Mar    4.977589
# Apr    4.204468
# May    4.325674
# Jun    3.873475
# Jul    3.895461
# Aug    3.367305
# Sep    3.377660
# Oct    2.610500
# Nov    3.685887
# Dec    4.176241
# dtype: float64

# %%
precip_var = precip.var()
precip_var
# Out:
# Jan    6.928862
# Feb    5.516660
# Mar    5.365444
# Apr    4.117096
# May    5.306409
# Jun    5.033206
# Jul    3.777012
# Aug    3.779876
# Sep    4.940099
# Oct    2.741659
# Nov    3.679274
# Dec    5.418022
# dtype: float64

# %%
precip.Apr
# Out:
# Year
# 1871     4.13
# 1872     5.91
# 1873     3.59
# 1874    11.84
# 1875     4.22
#         ...
# 2007     2.75
# 2008     7.20
# 2009     4.13
# 2010     3.48
# 2011     7.51
# Name: Apr, Length: 141, dtype: float64

# %% [markdown]
# Ok, now comes the most complicated part of Bayesian estimation: Let's pick pdfs for the $\gamma$ distribution's parameters $\alpha$ and $\beta$. We're taking numbers, and modeling them as distributions, so that we can take a probabilistic program to figure out the best values for these parameters. If you understand this, then you understand the most complicated part of Bayesian estimation theory!
#
# Let's firt try to model rainfall for the month of April, only.

# %%
precip.Apr.hist(normed=True, bins=30)
# Out:
# C:\Users\adwai\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py:309: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   ax.hist(values, bins=bins, **kwds)

# %% [markdown]
# ### Exercise 1:
#
# Start with the `Uniform` distribution. Rainfall for the month of April seems to go from 0 to 12 units, so let's pick the Uniform distribution to model the $\alpha$ parameter for our gamma function. The Uniform distribution also needs start and end parameters. We pick them to be wide enough to match the data. Then we model april rainfall with the Gamme distribution.
#
# This is the modeling part:
#
# ```python
# from pymc3 import Model, Uniform
#
# with Model() as rainfall_model:
#     ualpha = Uniform('ualpha', lower=0, upper=15)
#     ubeta = Uniform('ubeta', lower=0, upper=15)
#
# with rainfall_model:
#     april_like = Gamma('april_like', alpha=ualpha, beta=ubeta, observed=precip.Apr)
# ```
#
# This is the simulation part (the probabilistic program that yields the best values for parameters $\alpha$ and $\beta$). Be patient:
# ```python
# from pymc3 import fit
#
# with rainfall_model:
#     rainfall_trace = fit(random_seed=RANDOM_SEED).sample(1000)
# ```
#
# And this is how we plot our posterior pdf for rainfall (our model for april):
# ```python
# from pymc3 import plot_posterior
#
# plot_posterior(rainfall_trace[100:],
#                 varnames=['ualpha', 'ubeta'],
#                 color='#87ceeb');
# ```
#
# Then we check if our posterior model matches our histogram. If it does, we say "we found a good model for April!"!
#
# We can use the `gamma.pdf` function in `scipy.stats.distributions` to plot the distributions implied by the calculated alphas and betas.
#
# ```python
# from scipy.stats.distributions import gamma
#
# ualpha_posterior_mean = ...
# ubeta_posterior_mean = ...
#
# precip.Apr.hist(normed=True, bins=20)
# plt.plot(np.linspace(0, 25), gamma.pdf(np.linspace(0, 25), ualpha_posterior_mean, ubeta_posterior_mean))
# ```

# %%
from pymc3 import Model, Uniform, Gamma

with Model() as rainfall_model:
    ualpha = Uniform('ualpha', lower=0, upper=15)
    ubeta = Uniform('ubeta', lower=0, upper=15)

with rainfall_model:
    april_like = Gamma('april_like', alpha=ualpha, beta=ubeta, observed=precip.Apr)

# %%
from pymc3 import fit

with rainfall_model: 
    rainfall_trace = fit(random_seed=RANDOM_SEED).sample(1000)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:02<00:00 Average Loss = 368.14]
#     </div>
# Finished [100%]: Average Loss = 368

# %%
from pymc3 import plot_posterior

plot_posterior(rainfall_trace[100:], 
                varnames=['ualpha', 'ubeta'],
                color='#87ceeb');
# Out:
# C:\Users\adwai\anaconda3\lib\site-packages\pymc3\plots\__init__.py:35: UserWarning: Keyword argument `varnames` renamed to `var_names`, and will be removed in pymc3 3.8
#   warnings.warn('Keyword argument `{old}` renamed to `{new}`, and will be removed in pymc3 3.8'.format(old=old, new=new))
# C:\Users\adwai\anaconda3\lib\site-packages\arviz\data\io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,

# %%
from scipy.stats.distributions import gamma

ualpha_posterior_mean = 11
ubeta_posterior_mean = 2.7

precip.Apr.hist(normed=True, bins=20)
plt.plot(np.linspace(0, 25), gamma.pdf(np.linspace(0, 25), ualpha_posterior_mean, ubeta_posterior_mean))
# Out:
# C:\Users\adwai\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py:309: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   ax.hist(values, bins=bins, **kwds)

# %% [markdown]
# Are my hyperparameters not the right choice? Try different ones and improve on my model for extra credit.

# %% [markdown]
# ### Exercise 2:
#
# Did the Uniform distribution work out well in your modeling exercise above? Well, it didn't for professor!
#
# Let's try the `Normal` distribution instead. Please make sure to introduce **new** variables for your priors (xxxalpha, xxxbeta), as well as your simulation trace (xxxapril_like). Replace xxx with whatever you want.
#
# What's the right support for the normal (the right mean and standard deviation)? Pick a mean that centers the gaussian around the peak of the month, and a standard deviation that allows the gaussian to cover all the data.

# %%
math.sqrt(4.117096)
# Out:
# 2.029062837863825

# %%
import math

# %%
from pymc3 import Model, Uniform, Normal

with Model() as rainfall_model:
    nalpha = Normal('nalpha', mu=4.204468, sd=math.sqrt(4.117096))
    nbeta = Normal('nbeta', 4.204468, math.sqrt(4.117096))

with rainfall_model:
    april_like = Gamma('april_like', alpha=nalpha, beta=nbeta, observed=precip.Apr)
# Out:
# C:\Users\adwai\anaconda3\lib\site-packages\pymc3\distributions\continuous.py:103: UserWarning: The variable specified for alpha has negative support for Gamma, likely making it unsuitable for this parameter.
#   warnings.warn(msg)
# C:\Users\adwai\anaconda3\lib\site-packages\pymc3\distributions\continuous.py:103: UserWarning: The variable specified for beta has negative support for Gamma, likely making it unsuitable for this parameter.
#   warnings.warn(msg)

# %%
from pymc3 import fit

with rainfall_model:

    rainfall_trace = fit(random_seed=RANDOM_SEED).sample(1000)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:01<00:00 Average Loss = 329.43]
#     </div>
# Finished [100%]: Average Loss = 329.21

# %%
from pymc3 import plot_posterior

plot_posterior(rainfall_trace[100:], varnames=['nalpha','nbeta'], color='#87ceeb');

# %%
from scipy.stats.distributions import gamma

nalpha_posterior_mean = 6.6
nbeta_posterior_mean = 1.7

precip.Apr.hist(normed=True, bins=20)
plt.plot(np.linspace(0, 25), gamma.pdf(np.linspace(0, 25), nalpha_posterior_mean, nbeta_posterior_mean))
# Out:
# C:\Users\adwai\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py:309: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   ax.hist(values, bins=bins, **kwds)

# %% [markdown]
# ### Exercise 3:
#
# Let's try to accelerate things and try the exponential distribution, instead. Find the right number $x$ so that the distribution covers the range of possible precipitation values.  In other words, find the right value $y$ such that `Exponential.dist(1/3).random(size=10000)` covers from 0 to 12 for the month of April. Try different values out by plotting with:
#
# ```python
# sns.distplot(Exponential.dist(1/3).random(size=10000), kde=False);
# ```

# %%
from pymc3 import Model, Exponential

sns.distplot(Exponential.dist(1/3).random(size=10000), kde=True)

# %%
from pymc3 import Model, Exponential

with Model() as rainfall_model:
    ealpha = Exponential('ealpha', 1/3)
    ebeta = Exponential('ebeta', 1/3)
   
    #ealpha_posterior_mean = Exponential('exalpha', 1/3)
   #σ = Normal('σ', 4.204468, math.sqrt(4.117096))

with rainfall_model:
    april_like = Gamma('april_like', alpha=ealpha, beta=ebeta, observed=precip.Apr)

# %%
# %whos
# Out:
# Variable                Type             Data/Info
# --------------------------------------------------
# Exponential             type             <class 'pymc3.distributio<...>.continuous.Exponential'>
# Gamma                   type             <class 'pymc3.distributions.continuous.Gamma'>
# Model                   ContextMeta      <class 'pymc3.model.Model'>
# Normal                  type             <class 'pymc3.distributions.continuous.Normal'>
# RANDOM_SEED             int              20090425
# Uniform                 type             <class 'pymc3.distributions.continuous.Uniform'>
# april_like              ObservedRV       april_like
# ealpha_posterior_mean   TransformedRV    exalpha
# expon                   expon_gen        <scipy.stats._continuous_<...>ct at 0x0000017951F00F48>
# fit                     function         <function fit at 0x00000179586C29D8>
# gamma                   gamma_gen        <scipy.stats._continuous_<...>ct at 0x0000017951F31DC8>
# math                    module           <module 'math' (built-in)>
# nalpha_posterior_mean   float            4.204468
# nbeta_posterior_mean    float            2.029062837863825
# norm                    norm_gen         <scipy.stats._continuous_<...>ct at 0x0000017951EE3D08>
# np                      module           <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# pd                      module           <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# plot_posterior          function         <function plot_posterior at 0x00000179586D2168>
# plt                     module           <module 'matplotlib.pylab<...>s\\matplotlib\\pylab.py'>
# precip                  DataFrame               Jan   Feb   Mar   <...>\n[141 rows x 12 columns]
# precip_mean             Series           Jan    4.523688\nFeb    4<...> 4.176241\ndtype: float64
# precip_var              Series           Jan    6.928862\nFeb    5<...> 5.418022\ndtype: float64
# rainfall_model          Model            <pymc3.model.Model object at 0x000001795A5DC808>
# rainfall_trace          MultiTrace       <MultiTrace: 1 chains, 10<...> iterations, 2 variables>
# rainfall_trace_e        MultiTrace       <MultiTrace: 1 chains, 10<...> iterations, 2 variables>
# sns                     module           <module 'seaborn' from 'C<...>s\\seaborn\\__init__.py'>
# ssd                     module           <module 'scipy.stats.dist<...>stats\\distributions.py'>
# ualpha                  TransformedRV    ualpha
# ualpha_posterior_mean   int              11
# ubeta                   TransformedRV    ubeta
# ubeta_posterior_mean    float            2.7
# μ                       FreeRV           μ
# σ                       FreeRV           σ

# %%
from pymc3 import fit

with rainfall_model: 
    rainfall_trace_e = fit(random_seed=RANDOM_SEED).sample(1000)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:02<00:00 Average Loss = 317.35]
#     </div>
# Finished [100%]: Average Loss = 317.21

# %%
#Plotting the posterior pdf for rainfall model

from pymc3 import plot_posterior

plot_posterior(rainfall_trace_e[100:], 
                varnames=['ealpha','ebeta'],
                color='#87ceeb');
# Out:
# C:\Users\adwai\anaconda3\lib\site-packages\pymc3\plots\__init__.py:35: UserWarning: Keyword argument `varnames` renamed to `var_names`, and will be removed in pymc3 3.8
#   warnings.warn('Keyword argument `{old}` renamed to `{new}`, and will be removed in pymc3 3.8'.format(old=old, new=new))
# C:\Users\adwai\anaconda3\lib\site-packages\arviz\data\io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,

# %%
from scipy.stats.distributions import gamma

ealpha_posterior_mean = 3.6
ebeta_posterior_mean = 0.87

precip.Apr.hist(normed=True, bins=20)
plt.plot(np.linspace(0, 25), gamma.pdf(np.linspace(0, 25), ealpha_posterior_mean, ebeta_posterior_mean))
# Out:
# C:\Users\adwai\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py:309: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   ax.hist(values, bins=bins, **kwds)

# %%
dir(ssd)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_continuous_distns',
#  '_discrete_distns',
#  'absolute_import',
#  'alpha',
#  'alpha_gen',
#  'anglit',
#  'anglit_gen',
#  'arcsine',
#  'arcsine_gen',
#  'argus',
#  'argus_gen',
#  'bernoulli',
#  'bernoulli_gen',
#  'beta',
#  'beta_gen',
#  'betabinom',
#  'betabinom_gen',
#  'betaprime',
#  'betaprime_gen',
#  'binom',
#  'binom_gen',
#  'boltzmann',
#  'boltzmann_gen',
#  'bradford',
#  'bradford_gen',
#  'burr',
#  'burr12',
#  'burr12_gen',
#  'burr_gen',
#  'cauchy',
#  'cauchy_gen',
#  'chi',
#  'chi2',
#  'chi2_gen',
#  'chi_gen',
#  'cosine',
#  'cosine_gen',
#  'crystalball',
#  'crystalball_gen',
#  'dgamma',
#  'dgamma_gen',
#  'division',
#  'dlaplace',
#  'dlaplace_gen',
#  'dweibull',
#  'dweibull_gen',
#  'entropy',
#  'erlang',
#  'erlang_gen',
#  'expon',
#  'expon_gen',
#  'exponnorm',
#  'exponnorm_gen',
#  'exponpow',
#  'exponpow_gen',
#  'exponweib',
#  'exponweib_gen',
#  'f',
#  'f_gen',
#  'fatiguelife',
#  'fatiguelife_gen',
#  'fisk',
#  'fisk_gen',
#  'foldcauchy',
#  'foldcauchy_gen',
#  'foldnorm',
#  'foldnorm_gen',
#  'frechet_l',
#  'frechet_l_gen',
#  'frechet_r',
#  'frechet_r_gen',
#  'gamma',
#  'gamma_gen',
#  'gausshyper',
#  'gausshyper_gen',
#  'genexpon',
#  'genexpon_gen',
#  'genextreme',
#  'genextreme_gen',
#  'gengamma',
#  'gengamma_gen',
#  'genhalflogistic',
#  'genhalflogistic_gen',
#  'geninvgauss',
#  'geninvgauss_gen',
#  'genlogistic',
#  'genlogistic_gen',
#  'gennorm',
#  'gennorm_gen',
#  'genpareto',
#  'genpareto_gen',
#  'geom',
#  'geom_gen',
#  'gilbrat',
#  'gilbrat_gen',
#  'gompertz',
#  'gompertz_gen',
#  'gumbel_l',
#  'gumbel_l_gen',
#  'gumbel_r',
#  'gumbel_r_gen',
#  'halfcauchy',
#  'halfcauchy_gen',
#  'halfgennorm',
#  'halfgennorm_gen',
#  'halflogistic',
#  'halflogistic_gen',
#  'halfnorm',
#  'halfnorm_gen',
#  'hypergeom',
#  'hypergeom_gen',
#  'hypsecant',
#  'hypsecant_gen',
#  'invgamma',
#  'invgamma_gen',
#  'invgauss',
#  'invgauss_gen',
#  'invweibull',
#  'invweibull_gen',
#  'johnsonsb',
#  'johnsonsb_gen',
#  'johnsonsu',
#  'johnsonsu_gen',
#  'kappa3',
#  'kappa3_gen',
#  'kappa4',
#  'kappa4_gen',
#  'ksone',
#  'ksone_gen',
#  'kstwobign',
#  'kstwobign_gen',
#  'laplace',
#  'laplace_gen',
#  'levy',
#  'levy_gen',
#  'levy_l',
#  'levy_l_gen',
#  'levy_stable',
#  'levy_stable_gen',
#  'loggamma',
#  'loggamma_gen',
#  'logistic',
#  'logistic_gen',
#  'loglaplace',
#  'loglaplace_gen',
#  'lognorm',
#  'lognorm_gen',
#  'logser',
#  'logser_gen',
#  'loguniform',
#  'lomax',
#  'lomax_gen',
#  'maxwell',
#  'maxwell_gen',
#  'mielke',
#  'mielke_gen',
#  'moyal',
#  'moyal_gen',
#  'nakagami',
#  'nakagami_gen',
#  'nbinom',
#  'nbinom_gen',
#  'ncf',
#  'ncf_gen',
#  'nct',
#  'nct_gen',
#  'ncx2',
#  'ncx2_gen',
#  'norm',
#  'norm_gen',
#  'norminvgauss',
#  'norminvgauss_gen',
#  'pareto',
#  'pareto_gen',
#  'pearson3',
#  'pearson3_gen',
#  'planck',
#  'planck_gen',
#  'poisson',
#  'poisson_gen',
#  'powerlaw',
#  'powerlaw_gen',
#  'powerlognorm',
#  'powerlognorm_gen',
#  'powernorm',
#  'powernorm_gen',
#  'print_function',
#  'randint',
#  'randint_gen',
#  'rayleigh',
#  'rayleigh_gen',
#  'rdist',
#  'rdist_gen',
#  'recipinvgauss',
#  'recipinvgauss_gen',
#  'reciprocal',
#  'reciprocal_gen',
#  'rice',
#  'rice_gen',
#  'rv_continuous',
#  'rv_discrete',
#  'rv_frozen',
#  'rv_histogram',
#  'semicircular',
#  'semicircular_gen',
#  'skellam',
#  'skellam_gen',
#  'skew_norm_gen',
#  'skewnorm',
#  't',
#  't_gen',
#  'trapz',
#  'trapz_gen',
#  'triang',
#  'triang_gen',
#  'truncexpon',
#  'truncexpon_gen',
#  'truncnorm',
#  'truncnorm_gen',
#  'tukeylambda',
#  'tukeylambda_gen',
#  'uniform',
#  'uniform_gen',
#  'vonmises',
#  'vonmises_gen',
#  'vonmises_line',
#  'wald',
#  'wald_gen',
#  'weibull_max',
#  'weibull_max_gen',
#  'weibull_min',
#  'weibull_min_gen',
#  'wrapcauchy',
#  'wrapcauchy_gen',
#  'yulesimon',
#  'yulesimon_gen',
#  'zipf',
#  'zipf_gen']

# %% [markdown]
# ### Exercise 4:
#
# Do the month of January.

# %%
from pymc3 import Model, Uniform, Gamma

with Model() as rainfall_model:
    ualpha = Uniform('ualpha', lower=0, upper=15)
    ubeta = Uniform('ubeta', lower=0, upper=15)

with rainfall_model:
    jan_like = Gamma('jan_like', alpha=ualpha, beta=ubeta, observed=precip.Jan)

# %%
from pymc3 import fit

with rainfall_model: 
    rainfall_trace = fit(random_seed=RANDOM_SEED).sample(1000)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:02<00:00 Average Loss = 435.83]
#     </div>
# Finished [100%]: Average Loss = 435.64

# %%
from pymc3 import plot_posterior

plot_posterior(rainfall_trace[100:], 
                varnames=['ualpha', 'ubeta'],
                color='#87ceeb');
# Out:
# C:\Users\adwai\anaconda3\lib\site-packages\pymc3\plots\__init__.py:35: UserWarning: Keyword argument `varnames` renamed to `var_names`, and will be removed in pymc3 3.8
#   warnings.warn('Keyword argument `{old}` renamed to `{new}`, and will be removed in pymc3 3.8'.format(old=old, new=new))
# C:\Users\adwai\anaconda3\lib\site-packages\arviz\data\io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,

# %%
from scipy.stats.distributions import gamma

ualpha_posterior_mean = 11
ubeta_posterior_mean = 2.4

precip.Jan.hist(normed=True, bins=20)
plt.plot(np.linspace(0, 25), gamma.pdf(np.linspace(0, 25), ualpha_posterior_mean, ubeta_posterior_mean))
# Out:
# C:\Users\adwai\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py:309: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   ax.hist(values, bins=bins, **kwds)

# %%
from pymc3 import Model, Uniform, Normal

with Model() as rainfall_model:
    njalpha = Normal('njalpha', mu=4.523688, sd=math.sqrt(6.928862))
    njbeta = Normal('njbeta', 4.523688, math.sqrt(6.928862))

with rainfall_model:
    jan_like = Gamma('jan_like', alpha=njalpha, beta=njbeta, observed=precip.Jan)
# Out:
# C:\Users\adwai\anaconda3\lib\site-packages\pymc3\distributions\continuous.py:103: UserWarning: The variable specified for alpha has negative support for Gamma, likely making it unsuitable for this parameter.
#   warnings.warn(msg)
# C:\Users\adwai\anaconda3\lib\site-packages\pymc3\distributions\continuous.py:103: UserWarning: The variable specified for beta has negative support for Gamma, likely making it unsuitable for this parameter.
#   warnings.warn(msg)

# %%
from pymc3 import fit

with rainfall_model:

    rainfall_trace = fit(random_seed=RANDOM_SEED).sample(1000)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:02<00:00 Average Loss = 393.22]
#     </div>
# Finished [100%]: Average Loss = 393.12

# %%
from pymc3 import plot_posterior

plot_posterior(rainfall_trace, varnames=['njalpha','njbeta'], color='#87ceeb');
# Out:
# C:\Users\adwai\anaconda3\lib\site-packages\pymc3\plots\__init__.py:35: UserWarning: Keyword argument `varnames` renamed to `var_names`, and will be removed in pymc3 3.8
#   warnings.warn('Keyword argument `{old}` renamed to `{new}`, and will be removed in pymc3 3.8'.format(old=old, new=new))
# C:\Users\adwai\anaconda3\lib\site-packages\arviz\data\io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,

# %%
from scipy.stats.distributions import norm

nalpha_posterior_mean = 7.1
nbeta_posterior_mean = 1.8

precip.Jan.hist(normed=True, bins=20)
plt.plot(np.linspace(0, 25), gamma.pdf(np.linspace(0, 25), nalpha_posterior_mean, nbeta_posterior_mean))
# Out:
# C:\Users\adwai\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py:309: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   ax.hist(values, bins=bins, **kwds)

# %%
from pymc3 import Model, Exponential

sns.distplot(Exponential.dist(1/3).random(size=10000), kde=True)

# %%
from pymc3 import Model, Exponential

with Model() as rainfall_model:
    ealpha = Exponential('ealpha', 1/3)
    ebeta = Exponential('ebeta', 1/3)
   
    #ealpha_posterior_mean = Exponential('exalpha', 1/3)
   #σ = Normal('σ', 4.204468, math.sqrt(4.117096))

with rainfall_model:
    jan_like = Gamma('jan_like', alpha=ealpha, beta=ebeta, observed=precip.Jan)

# %%
from pymc3 import fit

with rainfall_model: 
    rainfall_trace_e = fit(random_seed=RANDOM_SEED).sample(1000)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:01<00:00 Average Loss = 341.88]
#     </div>
# Finished [100%]: Average Loss = 341.75

# %%
#Plotting the posterior pdf for rainfall model

from pymc3 import plot_posterior

plot_posterior(rainfall_trace_e[100:], 
                varnames=['ealpha','ebeta'],
                color='#87ceeb');
# Out:
# C:\Users\adwai\anaconda3\lib\site-packages\pymc3\plots\__init__.py:35: UserWarning: Keyword argument `varnames` renamed to `var_names`, and will be removed in pymc3 3.8
#   warnings.warn('Keyword argument `{old}` renamed to `{new}`, and will be removed in pymc3 3.8'.format(old=old, new=new))
# C:\Users\adwai\anaconda3\lib\site-packages\arviz\data\io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,

# %%
from scipy.stats.distributions import gamma

ealpha_posterior_mean = 3.4
ebeta_posterior_mean = 0.77

precip.Jan.hist(normed=True, bins=20)
plt.plot(np.linspace(0, 25), gamma.pdf(np.linspace(0, 25), ealpha_posterior_mean, ebeta_posterior_mean))
# Out:
# C:\Users\adwai\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py:309: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   ax.hist(values, bins=bins, **kwds)

# %% [markdown]
# ### (Deep thought) Exercise 5:
#
# How would you model *all* months together (*one* model, *all* months)? Is that even possible?

# %%
with Model() as rainfall_model:
    ualpha = Uniform('ualpha', lower=0, upper=15)
    ubeta = Uniform('ubeta', lower=0, upper=15)

with rainfall_model:
    year = Gamma('year', alpha=ualpha, beta=ubeta, observed=precip)
    
    
from pymc3 import fit

with rainfall_model: 
    rainfall_trace = fit(random_seed=RANDOM_SEED).sample(1000)
    
    
from pymc3 import plot_posterior
plot_posterior(rainfall_trace[100:], 
                    varnames=['ualpha', 'ubeta'],
                    color='#87ceeb');
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:02<00:00 Average Loss = 5,039]
#     </div>
# Finished [100%]: Average Loss = 5,036.5
# C:\Users\adwai\anaconda3\lib\site-packages\pymc3\plots\__init__.py:35: UserWarning: Keyword argument `varnames` renamed to `var_names`, and will be removed in pymc3 3.8
#   warnings.warn('Keyword argument `{old}` renamed to `{new}`, and will be removed in pymc3 3.8'.format(old=old, new=new))
# C:\Users\adwai\anaconda3\lib\site-packages\arviz\data\io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,

# %%
axs = precip.hist(density=True, figsize=(12,8), sharex = True, sharey =True, bins=20, grid=True)

for ax in axs.ravel():
    x = np.linspace(*ax.get_xlim())
    ax.plot(x, gamma.pdf(x,9.8,2.6))

# %%
from pymc3 import Model, Uniform, Gamma


for x in precip:
    
    
    with Model() as rainfall_model:
        ualpha = Uniform('ualpha', lower=0, upper=15)
        ubeta = Uniform('ubeta', lower=0, upper=15)

    with rainfall_model:
        month_like = Gamma('month_like', alpha=ualpha, beta=ubeta, observed=precip[x])
    
    
    from pymc3 import fit

    with rainfall_model: 
        rainfall_trace = fit(random_seed=RANDOM_SEED).sample(1000)
    
    
    from pymc3 import plot_posterior

    plot_posterior(rainfall_trace[100:], 
                    varnames=['ualpha', 'ubeta'],
                    color='#87ceeb');
plt.tight_layout()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:01<00:00 Average Loss = 435.83]
#     </div>
# Finished [100%]: Average Loss = 435.64
# C:\Users\adwai\anaconda3\lib\site-packages\pymc3\plots\__init__.py:35: UserWarning: Keyword argument `varnames` renamed to `var_names`, and will be removed in pymc3 3.8
#   warnings.warn('Keyword argument `{old}` renamed to `{new}`, and will be removed in pymc3 3.8'.format(old=old, new=new))
# C:\Users\adwai\anaconda3\lib\site-packages\arviz\data\io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:02<00:00 Average Loss = 421.91]
#     </div>
# Finished [100%]: Average Loss = 421.71
# C:\Users\adwai\anaconda3\lib\site-packages\pymc3\plots\__init__.py:35: UserWarning: Keyword argument `varnames` renamed to `var_names`, and will be removed in pymc3 3.8
#   warnings.warn('Keyword argument `{old}` renamed to `{new}`, and will be removed in pymc3 3.8'.format(old=old, new=new))
# C:\Users\adwai\anaconda3\lib\site-packages\arviz\data\io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:01<00:00 Average Loss = 389.63]
#     </div>
# Finished [100%]: Average Loss = 389.5
# C:\Users\adwai\anaconda3\lib\site-packages\pymc3\plots\__init__.py:35: UserWarning: Keyword argument `varnames` renamed to `var_names`, and will be removed in pymc3 3.8
#   warnings.warn('Keyword argument `{old}` renamed to `{new}`, and will be removed in pymc3 3.8'.format(old=old, new=new))
# C:\Users\adwai\anaconda3\lib\site-packages\arviz\data\io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:01<00:00 Average Loss = 366.68]
#     </div>
# Finished [100%]: Average Loss = 366.52
# C:\Users\adwai\anaconda3\lib\site-packages\pymc3\plots\__init__.py:35: UserWarning: Keyword argument `varnames` renamed to `var_names`, and will be removed in pymc3 3.8
#   warnings.warn('Keyword argument `{old}` renamed to `{new}`, and will be removed in pymc3 3.8'.format(old=old, new=new))
# C:\Users\adwai\anaconda3\lib\site-packages\arviz\data\io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:02<00:00 Average Loss = 391.54]
#     </div>
# Finished [100%]: Average Loss = 391.36
# C:\Users\adwai\anaconda3\lib\site-packages\pymc3\plots\__init__.py:35: UserWarning: Keyword argument `varnames` renamed to `var_names`, and will be removed in pymc3 3.8
#   warnings.warn('Keyword argument `{old}` renamed to `{new}`, and will be removed in pymc3 3.8'.format(old=old, new=new))
# C:\Users\adwai\anaconda3\lib\site-packages\arviz\data\io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:02<00:00 Average Loss = 420.8]
#     </div>
# Finished [100%]: Average Loss = 420.59
# C:\Users\adwai\anaconda3\lib\site-packages\pymc3\plots\__init__.py:35: UserWarning: Keyword argument `varnames` renamed to `var_names`, and will be removed in pymc3 3.8
#   warnings.warn('Keyword argument `{old}` renamed to `{new}`, and will be removed in pymc3 3.8'.format(old=old, new=new))
# C:\Users\adwai\anaconda3\lib\site-packages\arviz\data\io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:01<00:00 Average Loss = 379.95]
#     </div>
# Finished [100%]: Average Loss = 379.79
# C:\Users\adwai\anaconda3\lib\site-packages\pymc3\plots\__init__.py:35: UserWarning: Keyword argument `varnames` renamed to `var_names`, and will be removed in pymc3 3.8
#   warnings.warn('Keyword argument `{old}` renamed to `{new}`, and will be removed in pymc3 3.8'.format(old=old, new=new))
# C:\Users\adwai\anaconda3\lib\site-packages\arviz\data\io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:02<00:00 Average Loss = 374]
#     </div>
# Finished [100%]: Average Loss = 373.81
# C:\Users\adwai\anaconda3\lib\site-packages\pymc3\plots\__init__.py:35: UserWarning: Keyword argument `varnames` renamed to `var_names`, and will be removed in pymc3 3.8
#   warnings.warn('Keyword argument `{old}` renamed to `{new}`, and will be removed in pymc3 3.8'.format(old=old, new=new))
# C:\Users\adwai\anaconda3\lib\site-packages\arviz\data\io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:02<00:00 Average Loss = 443.22]
#     </div>
# Finished [100%]: Average Loss = 442.93
# C:\Users\adwai\anaconda3\lib\site-packages\pymc3\plots\__init__.py:35: UserWarning: Keyword argument `varnames` renamed to `var_names`, and will be removed in pymc3 3.8
#   warnings.warn('Keyword argument `{old}` renamed to `{new}`, and will be removed in pymc3 3.8'.format(old=old, new=new))
# C:\Users\adwai\anaconda3\lib\site-packages\arviz\data\io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:01<00:00 Average Loss = 389.15]
#     </div>
# Finished [100%]: Average Loss = 388.85
# C:\Users\adwai\anaconda3\lib\site-packages\pymc3\plots\__init__.py:35: UserWarning: Keyword argument `varnames` renamed to `var_names`, and will be removed in pymc3 3.8
#   warnings.warn('Keyword argument `{old}` renamed to `{new}`, and will be removed in pymc3 3.8'.format(old=old, new=new))
# C:\Users\adwai\anaconda3\lib\site-packages\arviz\data\io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:02<00:00 Average Loss = 385.38]
#     </div>
# Finished [100%]: Average Loss = 385.2
# C:\Users\adwai\anaconda3\lib\site-packages\pymc3\plots\__init__.py:35: UserWarning: Keyword argument `varnames` renamed to `var_names`, and will be removed in pymc3 3.8
#   warnings.warn('Keyword argument `{old}` renamed to `{new}`, and will be removed in pymc3 3.8'.format(old=old, new=new))
# C:\Users\adwai\anaconda3\lib\site-packages\arviz\data\io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:02<00:00 Average Loss = 401.07]
#     </div>
# Finished [100%]: Average Loss = 400.9
# C:\Users\adwai\anaconda3\lib\site-packages\pymc3\plots\__init__.py:35: UserWarning: Keyword argument `varnames` renamed to `var_names`, and will be removed in pymc3 3.8
#   warnings.warn('Keyword argument `{old}` renamed to `{new}`, and will be removed in pymc3 3.8'.format(old=old, new=new))
# C:\Users\adwai\anaconda3\lib\site-packages\arviz\data\io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,

# %%
mean_ualpha = {'Jan':11,'Feb': 10, 'Mar':12,'Apr':11,'May': 11,'Jun': 9.8,
               'Jul': 10,'Aug': 9.5,'Sep': 8.1,'Oct': 6.7,'Nov': 9.9,'Dec': 11}


mean_ubeta = {'Jan': 2.4,'Feb': 2.6,'Mar': 2.4,'Apr': 2.6,'May': 2.5,'Jun': 2.6,
              'Jul': 2.7,'Aug': 2.9,'Sep': 2.5,'Oct': 2.8,'Nov': 2.8,'Dec': 2.6}

# %%
axs = precip.hist(density=True, figsize=(12,8), sharex = True, sharey =True, bins=20, grid=True)

for ax in axs.ravel():
    countstr = str(count)
    m = str(ax.get_title())
    x = np.linspace(*ax.get_xlim())
    ax.plot(x, gamma.pdf(x, mean_ualpha[m], mean_ubeta[m]))

# %%
from pymc3 import Model, Exponential, Gamma

with Model() as rainfall_model:
    ealpha =Exponential('ealpha',1/3)
    ebeta =Exponential('ebeta',1/3)
    
with rainfall_model:
    year = Gamma('year',alpha=ealpha, beta = ebeta, observed=precip)
    
from pymc3 import fit

with rainfall_model: 
        rainfall_trace = fit(random_seed=RANDOM_SEED).sample(1000)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:02<00:00 Average Loss = 3,851.3]
#     </div>
# Finished [100%]: Average Loss = 3,849.9

# %%
plot_posterior(rainfall_trace[100:], 
                    varnames=['ealpha', 'ebeta'],
                    color='#87ceeb');
# Out:
# C:\Users\adwai\anaconda3\lib\site-packages\pymc3\plots\__init__.py:35: UserWarning: Keyword argument `varnames` renamed to `var_names`, and will be removed in pymc3 3.8
#   warnings.warn('Keyword argument `{old}` renamed to `{new}`, and will be removed in pymc3 3.8'.format(old=old, new=new))
# C:\Users\adwai\anaconda3\lib\site-packages\arviz\data\io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,

# %%
import matplotlib.pyplot as plt

axs = precip.hist(density=True, figsize=(12,8), sharex = True, sharey =True, bins=20, grid=True)

for ax in axs.ravel():
    x = np.linspace(*ax.get_xlim())
    ax.plot(x, gamma.pdf(x,3.1,0.8))

# %%
from pymc3 import Model, Uniform, Normal

with Model() as rainfall_model:
    nalpha = Normal('nalpha', mu=precip_mean.mean(), sd=math.sqrt(precip_var.mean()))
    nbeta = Normal('nbeta', precip_mean.mean(), math.sqrt(precip_var.mean()))

with rainfall_model:
    year = Gamma('year', alpha=nalpha, beta=nbeta, observed=precip)
    
    
from pymc3 import fit

with rainfall_model:
    rainfall_trace = fit(random_seed=RANDOM_SEED).sample(1000)
    
from pymc3 import plot_posterior

plot_posterior(rainfall_trace[100:], varnames=['nalpha','nbeta'], color='#87ceeb');
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:00<00:00 Average Loss = 4,168]
#     </div>
# Finished [100%]: Average Loss = 4,167.3
# C:\Users\adwai\anaconda3\lib\site-packages\pymc3\plots\__init__.py:35: UserWarning: Keyword argument `varnames` renamed to `var_names`, and will be removed in pymc3 3.8
#   warnings.warn('Keyword argument `{old}` renamed to `{new}`, and will be removed in pymc3 3.8'.format(old=old, new=new))
# C:\Users\adwai\anaconda3\lib\site-packages\arviz\data\io_pymc3.py:91: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,

# %%
pwd
# Out:
# 'C:\\Users\\adwai'

# %%
axs = precip.hist(density=True, figsize=(12,8), sharex = True, sharey =True, bins=20, grid=True)

for ax in axs.ravel():
    x = np.linspace(*ax.get_xlim())
    ax.plot(x, gamma.pdf(x,5.9,1.6))

# %%
# %whos
# Out:
# Variable                Type             Data/Info
# --------------------------------------------------
# Exponential             type             <class 'pymc3.distributio<...>.continuous.Exponential'>
# Gamma                   type             <class 'pymc3.distributions.continuous.Gamma'>
# Model                   ContextMeta      <class 'pymc3.model.Model'>
# Normal                  type             <class 'pymc3.distributions.continuous.Normal'>
# RANDOM_SEED             int              20090425
# Uniform                 type             <class 'pymc3.distributions.continuous.Uniform'>
# april_like              ObservedRV       april_like
# ax                      AxesSubplot      AxesSubplot(0.684722,0.125;0.215278x0.154082)
# axs                     ndarray          4x3: 12 elems, type `object`, 96 bytes
# count                   int              0
# countstr                str              0
# ealpha                  TransformedRV    ealpha
# ealpha_posterior_mean   float            3.4
# ebeta                   TransformedRV    ebeta
# ebeta_posterior_mean    float            0.77
# expon                   expon_gen        <scipy.stats._continuous_<...>ct at 0x0000017951F00F48>
# fit                     function         <function fit at 0x00000179586C29D8>
# gamma                   gamma_gen        <scipy.stats._continuous_<...>ct at 0x0000017951F31DC8>
# jan_like                ObservedRV       jan_like
# lambda1                 TransformedRV    lambda1
# m                       str              Sep
# math                    module           <module 'math' (built-in)>
# mean_ualpha             dict             n=12
# mean_ubeta              dict             n=12
# nalpha                  FreeRV           nalpha
# nalpha_posterior_mean   float            7.1
# nbeta                   FreeRV           nbeta
# nbeta_posterior_mean    float            1.8
# njalpha                 FreeRV           njalpha
# njbeta                  FreeRV           njbeta
# norm                    norm_gen         <scipy.stats._continuous_<...>ct at 0x0000017951EE3D08>
# np                      module           <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# pd                      module           <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# plot_posterior          function         <function plot_posterior at 0x00000179586D2168>
# plt                     module           <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# precip                  DataFrame               Jan   Feb   Mar   <...>\n[141 rows x 12 columns]
# precip_mean             Series           Jan    4.523688\nFeb    4<...> 4.176241\ndtype: float64
# precip_var              Series           Jan    6.928862\nFeb    5<...> 5.418022\ndtype: float64
# rainfall_model          Model            <pymc3.model.Model object at 0x000001795C713F48>
# rainfall_trace          MultiTrace       <MultiTrace: 1 chains, 10<...> iterations, 4 variables>
# rainfall_trace_e        MultiTrace       <MultiTrace: 1 chains, 10<...> iterations, 4 variables>
# sns                     module           <module 'seaborn' from 'C<...>s\\seaborn\\__init__.py'>
# ssd                     module           <module 'scipy.stats.dist<...>stats\\distributions.py'>
# ualpha                  TransformedRV    ualpha
# ualpha_posterior_mean   int              11
# ubeta                   TransformedRV    ubeta
# ubeta_posterior_mean    float            2.4
# x                       ndarray          50: 50 elems, type `float64`, 400 bytes
# year                    ObservedRV       year
# μ                       FreeRV           μ
# σ                       FreeRV           σ
