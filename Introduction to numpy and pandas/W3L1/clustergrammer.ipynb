# %% [markdown]
# <div style="text-align: right">INFO 6105 Data Sci Engineering Methods and Tools, Lecture 2 Day 2</div>
# <div style="text-align: right">Prof. Dino Konstantopoulos, 15 January 2020</div>
#
# # Clustergrammer

# %%
# !pip install clustergrammer_widget
# Out:
# Collecting clustergrammer_widget
#   Downloading clustergrammer_widget-1.13.3.tar.gz (654 kB)
# Requirement already satisfied: ipywidgets>=5.1.5 in c:\users\adwai\anaconda3\lib\site-packages (from clustergrammer_widget) (7.5.1)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in c:\users\adwai\anaconda3\lib\site-packages (from ipywidgets>=5.1.5->clustergrammer_widget) (7.12.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\adwai\anaconda3\lib\site-packages (from ipywidgets>=5.1.5->clustergrammer_widget) (5.1.4)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\adwai\anaconda3\lib\site-packages (from ipywidgets>=5.1.5->clustergrammer_widget) (4.3.3)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\adwai\anaconda3\lib\site-packages (from ipywidgets>=5.1.5->clustergrammer_widget) (5.0.4)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\adwai\anaconda3\lib\site-packages (from ipywidgets>=5.1.5->clustergrammer_widget) (3.5.1)
# Requirement already satisfied: decorator in c:\users\adwai\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=5.1.5->clustergrammer_widget) (4.4.1)
# Requirement already satisfied: jedi>=0.10 in c:\users\adwai\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=5.1.5->clustergrammer_widget) (0.14.1)
# Requirement already satisfied: pickleshare in c:\users\adwai\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=5.1.5->clustergrammer_widget) (0.7.5)
# Requirement already satisfied: backcall in c:\users\adwai\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=5.1.5->clustergrammer_widget) (0.1.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\adwai\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=5.1.5->clustergrammer_widget) (45.2.0.post20200210)
# Requirement already satisfied: pygments in c:\users\adwai\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=5.1.5->clustergrammer_widget) (2.5.2)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\adwai\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=5.1.5->clustergrammer_widget) (0.4.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\adwai\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=5.1.5->clustergrammer_widget) (3.0.3)
# Requirement already satisfied: jupyter-client in c:\users\adwai\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1.5->clustergrammer_widget) (5.3.4)
# Requirement already satisfied: tornado>=4.2 in c:\users\adwai\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=5.1.5->clustergrammer_widget) (6.0.3)
# Requirement already satisfied: ipython-genutils in c:\users\adwai\anaconda3\lib\site-packages (from traitlets>=4.3.1->ipywidgets>=5.1.5->clustergrammer_widget) (0.2.0)
# Requirement already satisfied: six in c:\users\adwai\anaconda3\lib\site-packages (from traitlets>=4.3.1->ipywidgets>=5.1.5->clustergrammer_widget) (1.14.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\adwai\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=5.1.5->clustergrammer_widget) (3.2.0)
# Requirement already satisfied: jupyter-core in c:\users\adwai\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=5.1.5->clustergrammer_widget) (4.6.1)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\adwai\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=5.1.5->clustergrammer_widget) (6.0.3)
# Requirement already satisfied: parso>=0.5.0 in c:\users\adwai\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=5.1.5->clustergrammer_widget) (0.5.2)
# Requirement already satisfied: wcwidth in c:\users\adwai\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=5.1.5->clustergrammer_widget) (0.1.8)
# Requirement already satisfied: pyzmq>=13 in c:\users\adwai\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=5.1.5->clustergrammer_widget) (18.1.1)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\adwai\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=5.1.5->clustergrammer_widget) (227)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\adwai\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=5.1.5->clustergrammer_widget) (2.8.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\adwai\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=5.1.5->clustergrammer_widget) (0.15.7)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\adwai\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=5.1.5->clustergrammer_widget) (1.5.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\adwai\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=5.1.5->clustergrammer_widget) (19.3.0)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\adwai\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.1.5->clustergrammer_widget) (0.8.3)
# Requirement already satisfied: prometheus-client in c:\users\adwai\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.1.5->clustergrammer_widget) (0.7.1)
# Requirement already satisfied: jinja2 in c:\users\adwai\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.1.5->clustergrammer_widget) (2.11.1)
# Requirement already satisfied: Send2Trash in c:\users\adwai\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.1.5->clustergrammer_widget) (1.5.0)
# Requirement already satisfied: nbconvert in c:\users\adwai\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.1.5->clustergrammer_widget) (5.6.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\adwai\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=5.1.5->clustergrammer_widget) (2.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\adwai\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.1.5->clustergrammer_widget) (1.1.1)
# Requirement already satisfied: testpath in c:\users\adwai\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.1.5->clustergrammer_widget) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\adwai\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.1.5->clustergrammer_widget) (1.4.2)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\adwai\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.1.5->clustergrammer_widget) (0.3)
# Requirement already satisfied: defusedxml in c:\users\adwai\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.1.5->clustergrammer_widget) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\adwai\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.1.5->clustergrammer_widget) (0.8.4)
# Requirement already satisfied: bleach in c:\users\adwai\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.1.5->clustergrammer_widget) (3.1.0)
# Requirement already satisfied: webencodings in c:\users\adwai\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=5.1.5->clustergrammer_widget) (0.5.1)
# Building wheels for collected packages: clustergrammer-widget
#   Building wheel for clustergrammer-widget (setup.py): started
#   Building wheel for clustergrammer-widget (setup.py): finished with status 'done'
#   Created wheel for clustergrammer-widget: filename=clustergrammer_widget-1.13.3-py2.py3-none-any.whl size=1285916 sha256=fe1c54ec7ca7b909f5e8d7278e0023f0c61ff558b03621c5d11427c5fa200e7f
#   Stored in directory: c:\users\adwai\appdata\local\pip\cache\wheels\64\ec\95\9ca058b27006a86b94ddeb18256969606069b40c641b159a81
# Successfully built clustergrammer-widget
# Installing collected packages: clustergrammer-widget
# Successfully installed clustergrammer-widget-1.13.3

# %%
# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok

# %%
# !jupyter nbextension enable --py --sys-prefix clustergrammer_widget
# Out:
# Enabling notebook extension clustergrammer_widget/extension...
#       - Validating: ok

# %%
# import widget classes and instantiate Network instance
from clustergrammer_widget import *
net = Network(clustergrammer_widget)

# %%
import numpy as np
import pandas as pd

# generate random matrix
num_rows = 10
num_cols = 10
np.random.seed(seed=100)
mat = np.random.rand(num_rows, num_cols)

# make row and col labels
rows = range(num_rows)
cols = range(num_cols)
rows = [str(i) for i in rows]
cols = [str(i) for i in cols]

# make pandas dataframe 
df6 = pd.DataFrame(data=mat, columns=cols, index=rows)
df6
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.543405  0.278369  0.424518  0.844776  0.004719  0.121569  0.670749
# 1  0.891322  0.209202  0.185328  0.108377  0.219697  0.978624  0.811683
# 2  0.431704  0.940030  0.817649  0.336112  0.175410  0.372832  0.005689
# 3  0.598843  0.603805  0.105148  0.381943  0.036476  0.890412  0.980921
# 4  0.742480  0.630184  0.581842  0.020439  0.210027  0.544685  0.769115
# 5  0.975006  0.884853  0.359508  0.598859  0.354796  0.340190  0.178081
# 6  0.376252  0.592805  0.629942  0.142600  0.933841  0.946380  0.602297
# 7  0.276765  0.246536  0.173608  0.966610  0.957013  0.597974  0.731301
# 8  0.508699  0.088460  0.528035  0.992158  0.395036  0.335596  0.805451
# 9  0.540405  0.296794  0.110788  0.312640  0.456979  0.658940  0.254258
#
#           7         8         9
# 0  0.825853  0.136707  0.575093
# 1  0.171941  0.816225  0.274074
# 2  0.252426  0.795663  0.015255
# 3  0.059942  0.890546  0.576901
# 4  0.250695  0.285896  0.852395
# 5  0.237694  0.044862  0.505431
# 6  0.387766  0.363188  0.204345
# 7  0.340385  0.092056  0.463498
# 8  0.754349  0.313066  0.634037
# 9  0.641101  0.200124  0.657625

# %%
net.load_df(df6)
net.cluster(enrichrgram=False)
net.widget()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-594178f38945> in <module>
#       1 net.load_df(df6)
# ----> 2 net.cluster(enrichrgram=False)
#       3 net.widget()
#
# ~\anaconda3\lib\site-packages\clustergrammer_widget\clustergrammer\__init__.py in cluster(self, dist_type, run_clustering, dendro, views, linkage_type, sim_mat, filter_sim, calc_cat_pval, run_enrichr, enrichrgram)
#      97                                    calc_cat_pval=calc_cat_pval,
#      98                                    run_enrichr=run_enrichr,
# ---> 99                                    enrichrgram=enrichrgram)
#     100
#     101   def make_clust(self, dist_type='cosine', run_clustering=True,
#
# ~\anaconda3\lib\site-packages\clustergrammer_widget\clustergrammer\make_clust_fun.py in make_clust(net, dist_type, run_clustering, dendro, requested_views, linkage_type, sim_mat, filter_sim, calc_cat_pval, sim_mat_views, run_enrichr, enrichrgram)
#      18   threshold = 0.0001
#      19   df = run_filter.df_filter_row_sum(df, threshold)
# ---> 20   df = run_filter.df_filter_col_sum(df, threshold)
#      21
#      22   # default setting
#
# ~\anaconda3\lib\site-packages\clustergrammer_widget\clustergrammer\run_filter.py in df_filter_col_sum(df, threshold, take_abs)
#      54     inst_rows = df_copy.index.tolist()
#      55     inst_cols = df_copy.columns.tolist()
# ---> 56     df['mat'] = grab_df_subset(df['mat'], inst_rows, inst_cols)
#      57
#      58     if 'mat_up' in df:
#
# ~\anaconda3\lib\site-packages\clustergrammer_widget\clustergrammer\run_filter.py in grab_df_subset(df, keep_rows, keep_cols)
#      72     df = df[keep_cols]
#      73   if keep_rows != 'all':
# ---> 74     df = df.ix[keep_rows]
#      75   return df
#      76
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'
